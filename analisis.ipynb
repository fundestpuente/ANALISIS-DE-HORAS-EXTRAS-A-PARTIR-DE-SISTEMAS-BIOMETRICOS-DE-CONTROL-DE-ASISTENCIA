# %% [markdown]
# # **Análisis de Horas Extras a Partir de Sistemas Biométricos de Control de Asistencia**
# ### Proyecto Final Samsung Innovation Campus – Módulo de Python (EC04)
#
# **Integrantes:**
# - Ulices Chingo
# - Sofia Feijóo
# - Brayan Maisincho
# - Esteban Quiña
# - Alan Palma

# %%
# Importar Librerías
import pandas as pd
import datetime
from datetime import datetime, timedelta
import os
import matplotlib.pyplot as plt

# Importar modulos propios
from src.procesamiento import cargar_datos, procesamiento
from src.horas_extras import horas_extras
from src.reporte import val_anormales, generar_reporte

# %% [markdown]
# ### Análisis del mes de Marzo

# %%
# Definir directorio y archivo
dir = "data/"
file_name = "miscelaneosmarzo2024.csv"

# Cargar y procesar datos
data = cargar_datos(dir + file_name)
totDATA = procesamiento(data)


# display(totDATA)
# Out:
# Cargando archivo de tipo: .csv
# Archivo cargado exitosamente!
# Columnas renombradas exitosamente.

# %%
# Calcular horas extras
horas_extras(totDATA, mes="marzo", feriados_csv="data/feriados_2024.csv")
# Out:
# 10 feriados cargados desde data/feriados_2024.csv
# Cálculo de horas extras completado.

# %%
# Generar reporte
out_name = "reporte_horas_extras_marzo2024.csv"
rep_marzo = generar_reporte(totDATA, file_name = out_name)
# Out:
# Directorio 'output_data' ya existe.
# Reporte guardado exitosamente en output_data/reporte_horas_extras_marzo2024.csv

# %%
display(rep_marzo)
# Out:
#            Nombre  Total horas extras 50%  Total horas extras 100%  \
# 0        Manuel F               40.350000                      0.0
# 1            Ruth               10.783333                      0.0
# 2        Graciela               15.933333                      0.0
# 3        Carla Na               24.416667                      0.0
# 4   Maria Narvaez               11.250000                      0.0
# 5        Duvan Ra                8.883333                      0.0
# 6        Stalin N                4.166667                      0.0
# 7        Lucely R                8.666667                      0.0
# 8        Marco Na               10.983333                      0.0
# 9           Karla              -15.866667                      0.0
# 10       Nancy Vi                5.533333                      0.0
# 11          Sonia               14.966667                      0.0
# 12       Diana Be               11.366667                      0.0
# ...

# %% [markdown]
# ### Análisis del mes de Abril

# %%
# Definir directorio y archivo
dir = "data/"
file_name = "miscelaneosabril2024.csv"

# Cargar y procesar datos
data = cargar_datos(dir + file_name)
totDATA = procesamiento(data)

# display(totDATA)
# Out:
# Cargando archivo de tipo: .csv
# Archivo cargado exitosamente!
# Columnas renombradas exitosamente.

# %%
# Calcular horas extras
horas_extras(totDATA, mes="abril", feriados_csv="data/feriados_2024.csv")
# Out:
# 10 feriados cargados desde data/feriados_2024.csv
# Cálculo de horas extras completado.

# %%
# Generar reporte
out_name = "reporte_horas_extras_abril2024.csv"
rep_abril = generar_reporte(totDATA, file_name = out_name)
# Out:
# Directorio 'output_data' ya existe.
# Reporte guardado exitosamente en output_data/reporte_horas_extras_abril2024.csv

# %%
display(rep_abril)
# Out:
#            Nombre  Total horas extras 50%  Total horas extras 100%  \
# 0        Manuel F               25.100000                      0.0
# 1            Ruth                8.566667                      0.0
# 2        Graciela               10.450000                      0.0
# 3        Carla Na               17.933333                      0.0
# 4   Maria Narvaez               15.633333                      0.0
# 5        Duvan Ra               16.433333                      0.0
# 6        Stalin N               15.816667                      0.0
# 7        Lucely R                4.433333                      0.0
# 8        Marco Na               25.500000                      0.0
# 9           Karla              -26.383333                      0.0
# 10       Nancy Vi                4.666667                      0.0
# 11          Sonia               14.850000                      0.0
# 12       Diana Be               17.316667                      0.0
# ...

# %% [markdown]
# ### Análisis del mes de Mayo

# %%
# Definir directorio y archivo
dir = "data/"
file_name = "miscelaneosmayo2024.csv"

# Cargar y procesar datos
data = cargar_datos(dir + file_name)
totDATA = procesamiento(data)

# display(totDATA)
# Out:
# Cargando archivo de tipo: .csv
# Archivo cargado exitosamente!
# Columnas renombradas exitosamente.

# %%
# Calcular horas extras
horas_extras(totDATA, mes="mayo", feriados_csv="data/feriados_2024.csv")
# Out:
# 10 feriados cargados desde data/feriados_2024.csv
# Cálculo de horas extras completado.

# %%
# Generar reporte
out_name = "reporte_horas_extras_mayo2024.csv"
rep_mayo = generar_reporte(totDATA, file_name = out_name)
# Out:
# Directorio 'output_data' ya existe.
# Reporte guardado exitosamente en output_data/reporte_horas_extras_mayo2024.csv

# %%
display(rep_mayo)
# Out:
#            Nombre  Total horas extras 50%  Total horas extras 100%  \
# 0        Manuel F               29.550000                 9.783333
# 1            Ruth               12.816667                 9.666667
# 2        Graciela               14.400000                 9.666667
# 3        Carla Na               11.616667                 9.700000
# 4   Maria Narvaez               13.033333                 9.683333
# 5        Duvan Ra               11.266667                 9.100000
# 6        Stalin N                9.583333                 8.900000
# 7        Lucely R               13.416667                 9.416667
# 8        Marco Na                3.316667                 9.033333
# 9           Karla               -4.633333                 8.500000
# 10       Nancy Vi               -1.900000                 9.683333
# 11          Sonia                3.650000                 9.566667
# 12       Diana Be                5.750000                 9.666667
# ...

# %% [markdown]
# ### Análisis del mes de Junio

# %%
# Definir directorio y archivo
dir = "data/"
file_name = "miscelaneosjunio2024.csv"

# Cargar y procesar datos
data = cargar_datos(dir + file_name)
totDATA = procesamiento(data)

# display(totDATA)
# Out:
# Cargando archivo de tipo: .csv
# Archivo cargado exitosamente!
# Columnas renombradas exitosamente.

# %%
# Calcular horas extras
horas_extras(totDATA, mes="junio", feriados_csv="data/feriados_2024.csv")
# Out:
# 10 feriados cargados desde data/feriados_2024.csv
# Cálculo de horas extras completado.

# %%
# Generar reporte
out_name = "reporte_horas_extras_junio2024.csv"
rep_junio = generar_reporte(totDATA, file_name = out_name)
# Out:
# Directorio 'output_data' ya existe.
# Reporte guardado exitosamente en output_data/reporte_horas_extras_junio2024.csv

# %%
display(rep_junio)
# Out:
#            Nombre  Total horas extras 50%  Total horas extras 100%  \
# 0        Manuel F               46.600000                      0.0
# 1            Ruth               19.333333                      0.0
# 2        Graciela               18.250000                      0.0
# 3        Carla Na               21.866667                      0.0
# 4   Maria Narvaez               20.600000                      0.0
# 5        Duvan Ra               16.533333                      0.0
# 6        Stalin N               14.216667                      0.0
# 7        Lucely R               15.800000                      0.0
# 8        Marco Na                7.683333                      0.0
# 9           Karla              -19.866667                      0.0
# 10       Nancy Vi               12.000000                      0.0
# 11       Diana Be                9.300000                      0.0
# 12    Anderson Pe                0.116667                      0.0
# ...

# %%
# Gráficas
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Configurar el estilo de las gráficas
#import scienceplots
#plt.style.use(['science', 'notebook', 'no-latex'])

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# Agregar columna de mes a cada dataframe
rep_marzo['Mes'] = 'Marzo'
rep_abril['Mes'] = 'Abril'
rep_mayo['Mes'] = 'Mayo'
rep_junio['Mes'] = 'Junio'

# Combinar todos los datos
todos_meses = pd.concat([rep_marzo, rep_abril, rep_mayo, rep_junio], ignore_index=True)

# Cálculo de Costo de Horas Extras

# Definimos el costo base (Costo de una hora ordinaria)
costo_hora_base = 10 
# Las horas extras al 50% se pagan al 150% (1.5 veces el costo base)
factor_recargo_50 = 1.5 

# Multiplicamos: Horas Físicas * Costo Base * Factor de Recargo
todos_meses['Costo Horas Extras'] = todos_meses['Total horas extras 50%'] * costo_hora_base * factor_recargo_50

print(f"Costo por Hora Extra (al 50%): ${costo_hora_base * factor_recargo_50:.2f}")

# 1. GRÁFICA COMPARATIVA: Evolución mensual del total de horas extras
plt.figure(figsize=(15, 12))

# Evolución del total de horas extras por mes
plt.subplot(2, 2, 1)
total_por_mes = todos_meses.groupby('Mes')['Total horas extras 50%'].sum()
meses = ['Marzo', 'Abril', 'Mayo', 'Junio']
total_por_mes = total_por_mes.reindex(meses)  # Asegurar orden correcto

plt.plot(meses, total_por_mes, marker='o', linewidth=2, markersize=8, color='blue')
plt.fill_between(meses, total_por_mes, alpha=0.3, color='blue')
plt.title('Evolución de Horas Extras por Mes', fontsize=14, fontweight='bold')
plt.ylabel('Total Horas Extras 50%')
plt.grid(True, alpha=0.3)

# Añadir valores en los puntos
for i, valor in enumerate(total_por_mes):
    plt.text(i, valor + 5, f'{valor:.1f}h', ha='center', va='bottom')

# 2. GRÁFICA: Evolución del costo mensual
plt.subplot(2, 2, 2)
costo_por_mes = todos_meses.groupby('Mes')['Costo Horas Extras'].sum()
costo_por_mes = costo_por_mes.reindex(meses)

plt.bar(meses, costo_por_mes, color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4'])
plt.title('Evolución del Costo en Horas Extras por Mes', fontsize=14, fontweight='bold')
plt.ylabel('Costo Total ($)')

# Añadir valores en las barras
for i, valor in enumerate(costo_por_mes):
    plt.text(i, valor + 10, f'${valor:.2f}', ha='center', va='bottom')

# 3. GRÁFICA: Top 5 empleados con más horas extras en todos los meses
plt.subplot(2, 2, 3)
top_5_global = todos_meses.groupby('Nombre')['Total horas extras 50%'].sum().nlargest(5)

plt.barh(top_5_global.index, top_5_global.values, color='lightcoral')
plt.xlabel('Total Horas Extras Acumuladas')
plt.title('Top 5 Empleados - Más Horas Extras (Acumulado 4 Meses)', fontsize=12, fontweight='bold')

# Añadir valores en las barras
for i, valor in enumerate(top_5_global.values):
    plt.text(valor + 1, i, f'{valor:.1f}h', va='center')

# 4. GRÁFICA: Distribución de empleados que hacen horas extras por mes
plt.subplot(2, 2, 4)
empleados_con_he_por_mes = []
for mes in meses:
    df_mes = todos_meses[todos_meses['Mes'] == mes]
    empleados_con_he = len(df_mes[df_mes['Total horas extras 50%'] > 0])
    empleados_con_he_por_mes.append(empleados_con_he)

plt.bar(meses, empleados_con_he_por_mes, color='lightgreen')
plt.title('Empleados con Horas Extras por Mes', fontsize=14, fontweight='bold')
plt.ylabel('Número de Empleados')

# Añadir valores en las barras
for i, valor in enumerate(empleados_con_he_por_mes):
    plt.text(i, valor + 0.1, f'{valor}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# 5. GRÁFICA: Comparación de los 5 empleados con más horas extras entre meses
empleados_top = top_5_global.index.tolist()

plt.figure(figsize=(15, 10))
for i, empleado in enumerate(empleados_top, 1):
    plt.subplot(2, 3, i)
    datos_empleado = todos_meses[todos_meses['Nombre'] == empleado]
    
    # Asegurar que tenemos datos para todos los meses
    datos_completos = []
    for mes in meses:
        dato_mes = datos_empleado[datos_empleado['Mes'] == mes]
        if len(dato_mes) > 0:
            datos_completos.append(dato_mes['Total horas extras 50%'].values[0])
        else:
            datos_completos.append(0)
    
    plt.plot(meses, datos_completos, marker='s', linewidth=2, markersize=6)
    plt.title(f'{empleado}', fontweight='bold')
    plt.ylabel('Horas Extras')
    plt.xticks(rotation=45)
    plt.grid(True, alpha=0.3)
    
    # Añadir valores en los puntos
    for j, valor in enumerate(datos_completos):
        plt.text(j, valor + 1, f'{valor:.1f}h', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# 6. GRÁFICA: Heatmap de horas extras por empleado y mes
plt.figure(figsize=(16, 10))

# Crear matriz para el heatmap
empleados_unicos = todos_meses['Nombre'].unique()
heatmap_data = []

for empleado in empleados_top:  # Usamos solo los top 5 para mejor visualización
    fila = []
    for mes in meses:
        dato = todos_meses[(todos_meses['Nombre'] == empleado) & (todos_meses['Mes'] == mes)]
        if len(dato) > 0:
            fila.append(dato['Total horas extras 50%'].values[0])
        else:
            fila.append(0)
    heatmap_data.append(fila)

heatmap_data = np.array(heatmap_data)

# Crear heatmap
plt.imshow(heatmap_data, cmap='YlOrRd', aspect='auto')
plt.colorbar(label='Horas Extras')
plt.xticks(range(len(meses)), meses)
plt.yticks(range(len(empleados_top)), empleados_top)
plt.xlabel('Mes')
plt.ylabel('Empleado')
plt.title('Heatmap: Horas Extras por Empleado y Mes', fontsize=14, fontweight='bold')

# Añadir valores en las celdas
for i in range(len(empleados_top)):
    for j in range(len(meses)):
        plt.text(j, i, f'{heatmap_data[i, j]:.1f}', 
                ha='center', va='center', 
                color='black' if heatmap_data[i, j] < heatmap_data.max()/2 else 'white')

plt.tight_layout()
plt.show()

# 7. GRÁFICA: Tendencia de los 3 empleados con más horas extras
plt.figure(figsize=(12, 8))

top_3_empleados = top_5_global.head(3).index.tolist()

for empleado in top_3_empleados:
    datos_empleado = todos_meses[todos_meses['Nombre'] == empleado]
    datos_por_mes = []
    
    for mes in meses:
        dato_mes = datos_empleado[datos_empleado['Mes'] == mes]
        if len(dato_mes) > 0:
            datos_por_mes.append(dato_mes['Total horas extras 50%'].values[0])
        else:
            datos_por_mes.append(0)
    
    plt.plot(meses, datos_por_mes, marker='o', linewidth=3, markersize=8, label=empleado)

plt.title('Tendencia de los 3 Empleados con Más Horas Extras', fontsize=14, fontweight='bold')
plt.ylabel('Horas Extras 50%')
plt.xlabel('Mes')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# RESUMEN ESTADÍSTICO COMPARATIVO
print("="*60)
print("ANÁLISIS COMPARATIVO - MARZO A JUNIO 2024")
print("="*60)

for mes in meses:
    df_mes = todos_meses[todos_meses['Mes'] == mes]
    total_horas = df_mes['Total horas extras 50%'].sum()
    total_costo = df_mes['Costo Horas Extras'].sum()
    empleados_con_he = len(df_mes[df_mes['Total horas extras 50%'] > 0])
    
    print(f"\n{mes}:")
    print(f"  • Total horas extras: {total_horas:.1f} h")
    print(f"  • Costo total: ${total_costo:.2f}")
    print(f"  • Empleados con HE: {empleados_con_he}/{len(df_mes)}")
    print(f"  • Promedio HE por empleado: {total_horas/len(df_mes):.1f} h")

# Análisis del empleado más consistente
empleado_consistente = todos_meses.groupby('Nombre')['Total horas extras 50%'].mean().idxmax()
promedio_consistente = todos_meses.groupby('Nombre')['Total horas extras 50%'].mean().max()

print(f"\nEMPLEADO MÁS CONSISTENTE:")
print(f"  • {empleado_consistente} - Promedio: {promedio_consistente:.1f} h/mes")

# Costo acumulado de 4 meses
costo_total_4_meses = todos_meses['Costo Horas Extras'].sum()
print(f"\nINVERSIÓN TOTAL 4 MESES: ${costo_total_4_meses:.2f}")
# Out:
# Costo por Hora Extra (al 50%): $15.00
# ...
# ANÁLISIS COMPARATIVO - MARZO A JUNIO 2024
# ...
#
# Marzo:
#   • Total horas extras: 163.2 h
#   • Costo total: $2448.25
#   • Empleados con HE: 14/15
#   • Promedio HE por empleado: 10.9 h
#
# Abril:
#   • Total horas extras: 170.9 h
#   • Costo total: $2563.75
#   • Empleados con HE: 14/15
#   • Promedio HE por empleado: 11.4 h
#
# Mayo:
#   • Total horas extras: 137.3 h
#   • Costo total: $2059.50
#   • Empleados con HE: 13/15
#   • Promedio HE por empleado: 9.2 h
#
# Junio:
#   • Total horas extras: 188.2 h
#   • Costo total: $2822.75
#   • Empleados con HE: 13/14
#   • Promedio HE por empleado: 13.4 h
#
# EMPLEADO MÁS CONSISTENTE:
#   • Manuel F - Promedio: 35.4 h/mes
#
# INVERSIÓN TOTAL 4 MESES: $9894.25
